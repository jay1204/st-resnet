# %%
import mxnet as mx
import numpy as np
import matplotlib.pyplot as plt
from utils import load_one_image, post_process_image, pre_process_image
from utils import *
from config import ucf, train_image, resnet_50, test_image
import os

# %matplotlib inline

# %%
new_symbol, new_arg_params,aux_params = mx.model.load_checkpoint(
                resnet_50.dir + resnet_50.name, train_image.load_epoch)

# %%
#mx.viz.plot_network(new_symbol)

# %%
#new_arg_params

# %%
#aux_params

# %%
classes_labels, train_videos_classes, test_videos_classes = get_ucf101_split(ucf.split_dir, ucf.split_id)

# %%
video_name = 'v_HighJump_g25_c04/frame000005.jpg'

# %%
video_path = os.path.join(ucf.image.dir, video_name)

# %%
image = load_one_image(video_path)

# %%
def plot_image(image):
    image1 = image.asnumpy()
    plt.imshow(image1)
    plt.show()

# %%
plot_image(image)

# %%
image.shape
w, h = (224,224)

# %%
# random_crop
plot_image(random_crop(image, 224, 224))

# %%
# random_crop
plot_image(random_crop(image, 224, 224))

# %%
# random_horizon_flip
plot_image(random_horizon_flip(image))

# %%
# random_corner_crop
plot_image(random_corner_crop(image, w, h))

# %%
# left_top_corner_crop
plot_image(left_top_corner_crop(image, w, h))

# %%
# left_bottom_corner_crop
plot_image(left_bottom_corner_crop(image, w, h))

# %%
# right_top_corner_crop
plot_image(right_top_corner_crop(image, w, h))

# %%
# right_bottom_corner_crop
plot_image(right_bottom_corner_crop(image, w, h))

# %%
# centre_crop
plot_image(centre_crop(image, w, h))

# %%
# random_border25_crop
plot_image(random_border25_crop(image, w, h))

# %%
# random_border25_crop
plot_image(random_border25_crop(image, w, h))

# %%
# random_border25_crop
plot_image(random_border25_crop(image, w, h))

# %%
# random_border25_crop
plot_image(random_border25_crop(image, w, h))

# %%
# random_border25_crop
plot_image(random_border25_crop(image, w, h))

# %%
# random_border25_crop
plot_image(random_border25_crop(image, w, h))

# %%
# random_border25_crop
plot_image(random_border25_crop(image, w, h))

# %%
# horizon_flip
plot_image(horizon_flip(image))
